# %%
#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in cleaned data
sat= pd.read_csv('../dataset/sat_cleaned.csv')
act= pd.read_csv('../dataset/sat_cleaned.csv')
act_and_sat= pd.read_csv('../dataset/act_sat_merged.csv')

# %%
sat.head()
# Out:
#    Unnamed: 0       state  sat_participation(%)  ebrw  math  sat_total  year
# 0           0     Alabama                     5   593   572       1165  2017
# 1           1      Alaska                    38   547   533       1080  2017
# 2           2     Arizona                    30   563   553       1116  2017
# 3           3    Arkansas                     3   614   594       1208  2017
# 4           4  California                    53   531   524       1055  2017

# %%
sat.drop(columns='Unnamed: 0',inplace= True)
sat.head()
# Out:
#         state  sat_participation(%)  ebrw  math  sat_total  year
# 0     Alabama                     5   593   572       1165  2017
# 1      Alaska                    38   547   533       1080  2017
# 2     Arizona                    30   563   553       1116  2017
# 3    Arkansas                     3   614   594       1208  2017
# 4  California                    53   531   524       1055  2017

# %%
act.head()
# Out:
#    Unnamed: 0       state  sat_participation(%)  ebrw  math  sat_total  year
# 0           0     Alabama                     5   593   572       1165  2017
# 1           1      Alaska                    38   547   533       1080  2017
# 2           2     Arizona                    30   563   553       1116  2017
# 3           3    Arkansas                     3   614   594       1208  2017
# 4           4  California                    53   531   524       1055  2017

# %%
act.drop(columns='Unnamed: 0',inplace= True)
act.head()
# Out:
#         state  sat_participation(%)  ebrw  math  sat_total  year
# 0     Alabama                     5   593   572       1165  2017
# 1      Alaska                    38   547   533       1080  2017
# 2     Arizona                    30   563   553       1116  2017
# 3    Arkansas                     3   614   594       1208  2017
# 4  California                    53   531   524       1055  2017

# %%
act_and_sat.head()
# Out:
#    Unnamed: 0       state  sat_participation(%)  sat_total  year  \
# 0           0     Alabama                     5       1165  2017
# 1           1      Alaska                    38       1080  2017
# 2           2     Arizona                    30       1116  2017
# 3           3    Arkansas                     3       1208  2017
# 4           4  California                    53       1055  2017
#
#    act_participation(%)  act_total       test_policy
# 0                   100       19.2      ACT required
# 1                    65       19.8  neither required
# 2                    62       19.7  neither required
# 3                   100       19.4  neither required
# 4                    31       22.8  neither required

# %%
act_and_sat.drop(columns='Unnamed: 0',inplace= True)
act_and_sat.head()
# Out:
#         state  sat_participation(%)  sat_total  year  act_participation(%)  \
# 0     Alabama                     5       1165  2017                   100
# 1      Alaska                    38       1080  2017                    65
# 2     Arizona                    30       1116  2017                    62
# 3    Arkansas                     3       1208  2017                   100
# 4  California                    53       1055  2017                    31
#
#    act_total       test_policy
# 0       19.2      ACT required
# 1       19.8  neither required
# 2       19.7  neither required
# 3       19.4  neither required
# 4       22.8  neither required

# %% [markdown]
# ### National level Analysis

# %%
act_and_sat.groupby(['test_policy'])[["sat_participation(%)",
                                      "act_participation(%)"]].mean()
# Out:
#                   sat_participation(%)  act_participation(%)
# test_policy
# ACT or SAT                   40.000000             75.555556
# ACT required                 12.404762             98.023810
# SAT required                 85.481481             30.555556
# neither required             49.013333             51.280000

# %%
plt.rcParams["figure.figsize"] = (10,8)
#plt.figure(figsize=(10,7))
act_and_sat.groupby(['test_policy'])[["sat_participation(%)","act_participation(%)"]].mean().plot(kind='bar')
plt.title("SAT and ACT Average Participation Rates by Test Policy",fontsize=20)
plt.xlabel("Test Policy",fontsize=16)
plt.ylabel("Avg Participation Rate (2017-2019)", fontsize=16)
plt.savefig("SAT and ACT Average Participation Rates by Test Policy")

# %% [markdown]
# - As expected, avg participation rates in the ACTs and SATs respectively were highest in states where each exam is mandatory.
# - In states where students must take at least one of the exams, the act recorded higher participation, showing that more students likely opted to take the ACTs.
# - Also in states were none of the exams are required, it appears that ACT was again prefered, although to a slight degree, compared with "either or" states.

# %%
act_and_sat[act_and_sat['year']==2017].sort_values(by=['sat_total'],ascending=False).head()
# Out:
#         state  sat_participation(%)  sat_total  year  act_participation(%)  \
# 23  Minnesota                     3       1295  2017                   100
# 49  Wisconsin                     3       1291  2017                   100
# 15       Iowa                     2       1275  2017                    67
# 25   Missouri                     3       1271  2017                   100
# 16     Kansas                     4       1260  2017                    73
#
#     act_total       test_policy
# 23       21.5  neither required
# 49       20.5      ACT required
# 15       21.9  neither required
# 25       20.4      ACT required
# 16       21.7  neither required

# %%
act_and_sat[act_and_sat['year']==2018].sort_values(by=['sat_total'],ascending=False).head()
# Out:
#             state  sat_participation(%)  sat_total  year  \
# 74      Minnesota                     4       1298  2018
# 100     Wisconsin                     3       1294  2018
# 85   North Dakota                     2       1283  2018
# 66           Iowa                     3       1265  2018
# 67         Kansas                     4       1265  2018
#
#      act_participation(%)  act_total       test_policy
# 74                     99       21.3  neither required
# 100                   100       20.5      ACT required
# 85                     98       20.3      ACT required
# 66                     68       21.8  neither required
# 67                     71       21.6  neither required

# %%
act_and_sat[act_and_sat['year']==2019].sort_values(by=['sat_total'],ascending=False).head()
# Out:
#             state  sat_participation(%)  sat_total  year  \
# 125     Minnesota                     4       1284  2019
# 151     Wisconsin                     3       1283  2019
# 143  South Dakota                     3       1268  2019
# 136  North Dakota                     2       1263  2019
# 129      Nebraska                     3       1260  2019
#
#      act_participation(%)  act_total       test_policy
# 125                    95       21.4  neither required
# 151                   100       20.3      ACT required
# 143                    75       21.6  neither required
# 136                    96       19.9      ACT required
# 129                   100       20.0      ACT required

# %% [markdown]
# Interestingly, the highest performing states in the SATs were states that either had no test requirement or
# required students to sit for the ACTs. The state of Minnesota recorded the highest SAT scores for the 3 years considered, but required neither exam.

# %%
act_and_sat[act_and_sat['year']==2017].sort_values(by=['sat_total'],ascending=True).head()
# Out:
#                    state  sat_participation(%)  sat_total  year  \
# 8   District of Columbia                   100        950  2017
# 7               Delaware                   100        996  2017
# 12                 Idaho                    93       1005  2017
# 22              Michigan                   100       1005  2017
# 19                 Maine                    95       1012  2017
#
#     act_participation(%)  act_total       test_policy
# 8                     32       24.2  neither required
# 7                     18       24.1      SAT required
# 12                    38       22.3        ACT or SAT
# 22                    29       24.1      SAT required
# 19                     8       24.3      SAT required

# %%
act_and_sat[act_and_sat['year']==2018].sort_values(by=['sat_total'],ascending=True).head()
# Out:
#                    state  sat_participation(%)  sat_total  year  \
# 59  District of Columbia                    92        977  2018
# 58              Delaware                   100        998  2018
# 99         West Virginia                    28        999  2018
# 63                 Idaho                   100       1001  2018
# 95                  Utah                     4       1010  2018
#
#     act_participation(%)  act_total       test_policy
# 59                    32       23.6  neither required
# 58                    17       23.8      SAT required
# 99                    65       20.3      SAT required
# 63                    36       22.3        ACT or SAT
# 95                   100       20.4      ACT required

# %%
act_and_sat[act_and_sat['year']==2019].sort_values(by=['sat_total'],ascending=True).head()
# Out:
#                     state  sat_participation(%)  sat_total  year  \
# 150         West Virginia                    99        943  2019
# 138              Oklahoma                    22        963  2019
# 110  District of Columbia                    94        975  2019
# 109              Delaware                   100        985  2019
# 114                 Idaho                   100        993  2019
#
#      act_participation(%)  act_total       test_policy
# 150                    49       20.8      SAT required
# 138                   100       18.9  neither required
# 110                    32       23.5  neither required
# 109                    13       24.1      SAT required
# 114                    31       22.5        ACT or SAT

# %% [markdown]
# It appears there is no pattern for the least performing states as all 4 policies feature.

# %%
act_and_sat[act_and_sat['year']==2017].sort_values(by=['act_total'],ascending=False).head()
# Out:
#                    state  sat_participation(%)  sat_total  year  \
# 29         New Hampshire                    96       1052  2017
# 21         Massachusetts                    76       1107  2017
# 6            Connecticut                   100       1041  2017
# 19                 Maine                    95       1012  2017
# 8   District of Columbia                   100        950  2017
#
#     act_participation(%)  act_total       test_policy
# 29                    18       25.5      SAT required
# 21                    29       25.4  neither required
# 6                     31       25.2      SAT required
# 19                     8       24.3      SAT required
# 8                     32       24.2  neither required

# %%
act_and_sat[act_and_sat['year']==2018].sort_values(by=['act_total'],ascending=False).head()
# Out:
#             state  sat_participation(%)  sat_total  year  \
# 57    Connecticut                   100       1053  2018
# 72  Massachusetts                    80       1125  2018
# 80  New Hampshire                    96       1063  2018
# 83       New York                    79       1068  2018
# 73       Michigan                   100       1011  2018
#
#     act_participation(%)  act_total       test_policy
# 57                    26       25.6      SAT required
# 72                    25       25.5  neither required
# 80                    16       25.1      SAT required
# 83                    27       24.5  neither required
# 73                    22       24.2      SAT required

# %%
act_and_sat[act_and_sat['year']==2019].sort_values(by=['act_total'],ascending=False).head()
# Out:
#              state  sat_participation(%)  sat_total  year  \
# 123  Massachusetts                    81       1120  2019
# 108    Connecticut                   100       1046  2019
# 131  New Hampshire                    95       1059  2019
# 141   Rhode Island                   100        995  2019
# 134       New York                    79       1064  2019
#
#      act_participation(%)  act_total       test_policy
# 123                    21       25.5  neither required
# 108                    22       25.5      SAT required
# 131                    14       25.0      SAT required
# 141                    12       24.7      SAT required
# 134                    22       24.5  neither required

# %% [markdown]
# Interestingly, the highest performing states in the ACTs were states that either had no test requirement or
# required students to sit for the SATS.

# %%
act_and_sat[act_and_sat['year']==2017].sort_values(by=['act_total'],ascending=True).head()
# Out:
#              state  sat_participation(%)  sat_total  year  \
# 28          Nevada                    26       1116  2017
# 24     Mississippi                     2       1242  2017
# 40  South Carolina                    50       1064  2017
# 11          Hawaii                    55       1085  2017
# 33  North Carolina                    49       1081  2017
#
#     act_participation(%)  act_total       test_policy
# 28                   100       17.8      ACT required
# 24                   100       18.6      ACT required
# 40                   100       18.7  neither required
# 11                    90       19.0      ACT required
# 33                   100       19.1      ACT required

# %%
act_and_sat[act_and_sat['year']==2018].sort_values(by=['act_total'],ascending=True).head()
# Out:
#              state  sat_participation(%)  sat_total  year  \
# 79          Nevada                    23       1140  2018
# 91  South Carolina                    55       1070  2018
# 75     Mississippi                     3       1236  2018
# 62          Hawaii                    56       1010  2018
# 51         Alabama                     6       1166  2018
#
#     act_participation(%)  act_total       test_policy
# 79                   100       17.7      ACT required
# 91                   100       18.3  neither required
# 75                   100       18.6      ACT required
# 62                    89       18.9      ACT required
# 51                   100       19.1      ACT required

# %%
act_and_sat[act_and_sat['year']==2019].sort_values(by=['act_total'],ascending=True).head()
# Out:
#               state  sat_participation(%)  sat_total  year  \
# 130          Nevada                    20       1156  2019
# 126     Mississippi                     3       1237  2019
# 142  South Carolina                    68       1030  2019
# 120       Louisiana                     5       1200  2019
# 102         Alabama                     7       1143  2019
#
#      act_participation(%)  act_total       test_policy
# 130                   100       17.9      ACT required
# 126                   100       18.4      ACT required
# 142                    78       18.8  neither required
# 120                   100       18.8      ACT required
# 102                   100       18.9      ACT required

# %% [markdown]
# on the flip side, the bottom performers in the ACTs either required the ACT exam or none at all.

# %%
act_and_sat
# Out:
#              state  sat_participation(%)  sat_total  year  \
# 0          Alabama                     5       1165  2017
# 1           Alaska                    38       1080  2017
# 2          Arizona                    30       1116  2017
# 3         Arkansas                     3       1208  2017
# 4       California                    53       1055  2017
# ..             ...                   ...        ...   ...
# 148       Virginia                    68       1119  2019
# 149     Washington                    70       1074  2019
# 150  West Virginia                    99        943  2019
# 151      Wisconsin                     3       1283  2019
# 152        Wyoming                     3       1238  2019
#
#      act_participation(%)  act_total       test_policy
# 0                     100       19.2      ACT required
# 1                      65       19.8  neither required
# 2                      62       19.7  neither required
# 3                     100       19.4  neither required
# 4                      31       22.8  neither required
# ..                    ...        ...               ...
# 148                    21       24.0  neither required
# 149                    24       22.1  neither required
# 150                    49       20.8      SAT required
# 151                   100       20.3      ACT required
# 152                   100       19.8      ACT required
#
# [153 rows x 7 columns]

# %%
act_and_sat.groupby(['year','test_policy'])[["sat_participation(%)",
                                      "act_participation(%)"]].mean()
# Out:
#                        sat_participation(%)  act_participation(%)
# year test_policy
# 2017 ACT or SAT                   36.666667             71.000000
#      ACT required                 12.285714             98.000000
#      SAT required                 66.222222             43.000000
#      neither required             46.080000             54.240000
# 2018 ACT or SAT                   41.333333             78.666667
#      ACT required                 12.642857             99.071429
#      SAT required                 91.000000             26.777778
#      neither required             48.520000             51.360000
# 2019 ACT or SAT                   42.000000             77.000000
#      ACT required                 12.285714             97.000000
#      SAT required                 99.222222             21.888889
#      neither required             52.440000             48.240000

# %%
plt.rcParams["figure.figsize"] = (10,8)

act_and_sat[act_and_sat['test_policy']=='ACT required'].groupby(['year'])[["sat_participation(%)",
                                      "act_participation(%)"]].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
act_and_sat.groupby(['test_policy'])["sat_total"].mean().plot(kind)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-0f7ba9639c4d> in <module>
# ----> 1 act_and_sat.groupby(['test_policy'])["sat_total"].mean().plot(kind)
#
# NameError: name 'kind' is not defined

# %% [markdown]
# - in

# %%
act_and_sat.groupby(['year'])['sat_total'].mean().plot(kind='bar')

# %%
act_and_sat.groupby(['year'])['act_total'].mean().plot(kind='bar')

# %% [markdown]
# Average total sat scores and act scores for all groups barely changed between 2017 and 2019.

# %%
act_and_sat.groupby(['test_policy','year'])['sat_total'].mean().plot(kind='barh')

act_and_sat[act_and_sat['']]
# Out:
# <AxesSubplot:ylabel='test_policy,year'>

# %%
#view descriptive stats 
sat.agg(['mean','median'])
# Out:
#         participation_rate (%)        ebrw        math        total    year
# mean                 44.869281  564.535948  552.019608  1119.732026  2018.0
# median               50.000000  554.000000  546.000000  1099.000000  2018.0

# %%
#plot of national test scores
sat.groupby(['year'])[['participation_rate (%)']].mean().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Average national participation rate grew year on year.

# %%
#plot of national test scores
sat.groupby(['year'])[['ebrw','math','total']].mean().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# average national test scores remained fairly stable between 2017-2019.

# %% [markdown]
# ### Interesting Insights
#
# - median national participation rate between 2017-2019 was 44.9%
# - mean national participation rate between 2017-2019 was 50% i.e. about half the students in the country participated in the SAT's

# %% [markdown]
# ## State Analysis

# %%
sat.head()
# Out:
#         state  participation_rate (%)  ebrw  math  total  year
# 0     Alabama                       5   593   572   1165  2017
# 1      Alaska                      38   547   533   1080  2017
# 2     Arizona                      30   563   553   1116  2017
# 3    Arkansas                       3   614   594   1208  2017
# 4  California                      53   531   524   1055  2017

# %%
#states with highest participation rate in 2017
sat[sat['year']==2017].sort_values('participation_rate (%)', 
                                   ascending=False).head(10)
# Out:
#                    state  participation_rate (%)  ebrw  math  total  year
# 8   District of Columbia                     100   482   468    950  2017
# 22              Michigan                     100   509   495   1005  2017
# 6            Connecticut                     100   530   512   1041  2017
# 7               Delaware                     100   503   492    996  2017
# 29         New Hampshire                      96   532   520   1052  2017
# 19                 Maine                      95   513   499   1012  2017
# 12                 Idaho                      93   513   493   1005  2017
# 9                Florida                      83   520   497   1017  2017
# 21         Massachusetts                      76   555   551   1107  2017
# 39          Rhode Island                      71   539   524   1062  2017

# %%
#states with highest participation rate in 2018
sat[sat['year']==2018].sort_values('participation_rate (%)', 
                                   ascending=False).head(10)
# Out:
#                    state  participation_rate (%)  ebrw  math  total  year
# 56              Colorado                     100   519   506   1025  2018
# 57           Connecticut                     100   535   519   1053  2018
# 58              Delaware                     100   505   492    998  2018
# 73              Michigan                     100   511   499   1011  2018
# 63                 Idaho                     100   508   493   1001  2018
# 70                 Maine                      99   512   501   1013  2018
# 64              Illinois                      99   513   506   1019  2018
# 90          Rhode Island                      97   513   505   1018  2018
# 80         New Hampshire                      96   535   528   1063  2018
# 59  District of Columbia                      92   497   480    977  2018

# %%
#states with highest participation rate in 2019
sat[sat['year']==2019].sort_values('participation_rate (%)', 
                                   ascending=False).head(10)
# Out:
#              state  participation_rate (%)  ebrw  math  total  year
# 141   Rhode Island                     100   503   492    995  2019
# 115       Illinois                     100   509   504   1013  2019
# 124       Michigan                     100   507   496   1003  2019
# 107       Colorado                     100   518   506   1024  2019
# 108    Connecticut                     100   529   516   1046  2019
# 109       Delaware                     100   499   486    985  2019
# 111        Florida                     100   516   483    999  2019
# 114          Idaho                     100   505   488    993  2019
# 121          Maine                      99   512   502   1013  2019
# 150  West Virginia                      99   483   460    943  2019

# %%
#states with lowest participation rate in 2017
sat[sat['year']==2017].sort_values('participation_rate (%)', 
                                   ascending=False).tail(10)
# Out:
#            state  participation_rate (%)  ebrw  math  total  year
# 49     Wisconsin                       3   642   649   1291  2017
# 25      Missouri                       3   640   631   1271  2017
# 41  South Dakota                       3   612   603   1216  2017
# 27      Nebraska                       3   629   625   1253  2017
# 23     Minnesota                       3   644   651   1295  2017
# 3       Arkansas                       3   614   594   1208  2017
# 50       Wyoming                       3   626   604   1230  2017
# 34  North Dakota                       2   635   621   1256  2017
# 24   Mississippi                       2   634   607   1242  2017
# 15          Iowa                       2   641   635   1275  2017

# %%
#states with lowest participation rate in 2018
sat[sat['year']==2018].sort_values('participation_rate (%)', 
                                   ascending=False).tail(10)
# Out:
#             state  participation_rate (%)  ebrw  math  total  year
# 69      Louisiana                       4   615   595   1210  2018
# 68       Kentucky                       4   630   618   1248  2018
# 67         Kansas                       4   633   631   1265  2018
# 92   South Dakota                       3   622   618   1240  2018
# 78       Nebraska                       3   629   623   1252  2018
# 75    Mississippi                       3   630   606   1236  2018
# 66           Iowa                       3   634   631   1265  2018
# 100     Wisconsin                       3   641   653   1294  2018
# 101       Wyoming                       3   633   625   1257  2018
# 85   North Dakota                       2   640   643   1283  2018

# %%
#states with lowest participation rate in 2019
sat[sat['year']==2019].sort_values('participation_rate (%)', 
                                   ascending=False).tail(10)
# Out:
#             state  participation_rate (%)  ebrw  math  total  year
# 125     Minnesota                       4   636   648   1284  2019
# 119      Kentucky                       4   620   612   1232  2019
# 118        Kansas                       4   618   623   1241  2019
# 143  South Dakota                       3   633   635   1268  2019
# 129      Nebraska                       3   628   631   1260  2019
# 126   Mississippi                       3   628   608   1237  2019
# 117          Iowa                       3   622   622   1244  2019
# 151     Wisconsin                       3   635   648   1283  2019
# 152       Wyoming                       3   623   615   1238  2019
# 136  North Dakota                       2   627   636   1263  2019

# %%
sat.sort_values('participation_rate (%)', ascending=False).head()
# Out:
#         state  participation_rate (%)  ebrw  math  total  year
# 109  Delaware                     100   499   486    985  2019
# 111   Florida                     100   516   483    999  2019
# 115  Illinois                     100   509   504   1013  2019
# 114     Idaho                     100   505   488    993  2019
# 56   Colorado                     100   519   506   1025  2018

# %%
#view descriptive stats
sat.describe()
# Out:
#        participation_rate (%)        ebrw        math        total  \
# count              153.000000  153.000000  153.000000   153.000000
# mean                44.869281  564.535948  552.019608  1119.732026
# std                 37.094419   46.301362   63.246434    94.162654
# min                  2.000000  480.000000   52.000000   943.000000
# 25%                  4.000000  531.000000  521.000000  1053.000000
# 50%                 50.000000  554.000000  546.000000  1099.000000
# 75%                 76.000000  614.000000  596.000000  1210.000000
# max                100.000000  644.000000  655.000000  1298.000000
#
#               year
# count   153.000000
# mean   2018.000000
# std       0.819178
# min    2017.000000
# 25%    2017.000000
# 50%    2018.000000
# 75%    2019.000000
# max    2019.000000

# %%
sat
# Out:
#              state  participation_rate (%)  ebrw  math  total  year
# 0          Alabama                       5   593   572   1165  2017
# 1           Alaska                      38   547   533   1080  2017
# 2          Arizona                      30   563   553   1116  2017
# 3         Arkansas                       3   614   594   1208  2017
# 4       California                      53   531   524   1055  2017
# ..             ...                     ...   ...   ...    ...   ...
# 148       Virginia                      68   567   551   1119  2019
# 149     Washington                      70   539   535   1074  2019
# 150  West Virginia                      99   483   460    943  2019
# 151      Wisconsin                       3   635   648   1283  2019
# 152        Wyoming                       3   623   615   1238  2019
#
# [153 rows x 6 columns]
